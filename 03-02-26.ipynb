# %%
import numpy as np

# %%
x= np.array([1, 3, 5, 7, 8, 9, 10, 15])
y= np.array([10,20,30,40, 50, 60, 70, 80])

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)       
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr
    
# strong correlation
print(Pearson_correlation(x,y))
print(Pearson_correlation(x,x))
print(Pearson_correlation(y,y))
print(Pearson_correlation(y,x))
# Out:
# 0.974894414261588
# 1.0
# 1.0
# 0.974894414261588

# %%
x1= np.array([1, 3, 5, 7, 8, 9, 10, 15])
y1= np.array([80,70,60,50,40,30,20,10])

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)       
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr
    
# strong correlation
print(Pearson_correlation(x1,y1))
print(Pearson_correlation(x1,x1))
print(Pearson_correlation(y1,y1))
print(Pearson_correlation(y1,x1))
# Out:
# -0.974894414261588
# 1.0
# 1.0
# -0.974894414261588

# %%
# Complete Random Values for both x and y

# %%
x2= np.array([5, 4, 7, 8, 6, 2, 3, 1])
y2= np.array([20, 50, 40, 70, 60, 30, 42, 55])

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)       
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr
    
print(Pearson_correlation(x2,y2))
print(Pearson_correlation(x2,x2))
print(Pearson_correlation(y2,y2))
print(Pearson_correlation(y2,x2))
# Out:
# 0.3208302644842707
# 1.0
# 1.0
# 0.3208302644842707

# %%
# Checking Correlation for Data
import pandas as pd

# %%
df = pd.read_csv('insurance.csv')

# %%
# Age With Children
x3 = np.array(df.children)
y3 = np.array(df.age)

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)       
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr
    
print(Pearson_correlation(x3,y3))
print(Pearson_correlation(y3,x3))
# Out:
# 0.04246899855884949
# 0.04246899855884949

# %%
# Age With Bmi
x4 = np.array(df.bmi)
y4 = np.array(df.age)

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)       
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr
    
print(Pearson_correlation(x4,y4))
print(Pearson_correlation(y4,x4))
# Out:
# 0.10519423088835637
# 0.10519423088835637

# %%
# Children and Charges
x5 = np.array(df.children)
y5 = np.array(df.charges)

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)       
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr
    
print(Pearson_correlation(x5,y5))
print(Pearson_correlation(y5,x5))
# Out:
# 0.0679982268479051
# 0.0679982268479051

# %%
df_new = pd.read_csv('insurance_numeric.csv')

# %%
# Self Correlation like age with age bmi with bmi are 1.0
# Strong Correlation age with charges
corre = df_new.corr(method = 'pearson')
print(corre)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.105194  0.042469  0.299008
# bmi       0.105194  1.000000  0.018961  0.191503
# children  0.042469  0.018961  1.000000  0.067998
# charges   0.299008  0.191503  0.067998  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip in
