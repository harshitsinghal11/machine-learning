# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female     NaN         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1321.000000  1338.000000   1338.000000
# mean     39.207025    30.656658     1.094918  13270.422265
# std      14.049960     6.102268     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.315000     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.675000     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.shape
# Out:
# (1338, 7)

# %%
plt.pie(df['smoker'].value_counts(), labels=[
        'Yes', 'No'], autopct='%.f%%', shadow=True)
plt.title('Outcome Proportionality')
plt.show()

# %%
# This command will help in printing the columns names

# %%
print(list(df.columns))
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1321 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Missing data Handling

# %%
df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False   True     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# bmi         17
# children     0
# smoker       0
# region       0
# charges      0
# dtype: int64

# %%
# If There are Null Values onw suggestion is to remove the null value

# %%
df.dropna()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 21     30  female  32.400         1     no  southwest   4149.73600
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1321 rows x 7 columns]

# %%
# FIll the Missing Value

# %%
df['bmi'] = df['bmi'].fillna(0)

# %%
df.drop(4).head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female   0.000         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 5   31  female   0.000         0     no  southeast   3756.62160

# %%
df.drop(10).head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female   0.000         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female   0.000         0     no  southeast   3756.62160
# 6   46  female   0.000         1     no  southeast   8240.58960
# 7   37  female   0.000         3     no  northwest   7281.50560
# 8   37    male   0.000         2     no  northeast   6406.41070
# 9   60  female   0.000         0     no  northwest  28923.13692

# %%
df = df.rename({0: "girl"})

# %%
print(df)
# Out:
#       age     sex     bmi  children smoker     region      charges
# girl   19  female   0.000         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Creating new Columns

# %%
df['salary'] = 1

# %%
df.head()
# Out:
#       age     sex     bmi  children smoker     region      charges  salary
# girl   19  female   0.000         0    yes  southwest  16884.92400       1
# 1      18    male  33.770         1     no  southeast   1725.55230       1
# 2      28    male  33.000         3     no  southeast   4449.46200       1
# 3      33    male  22.705         0     no  northwest  21984.47061       1
# 4      32    male  28.880         0     no  northwest   3866.85520       1
